# %%
from tagger.viewsets.received_items import ReceivedItemViewSet
from tagger.models.inventory import Inventory, ProductType, InventoryStatus
from tagger.core.mongo.models.product import Product
from tagger.core.mongo.models.alloff_product import AlloffProduct
from tagger.core.mongo.models.order import Order
from bson import ObjectId
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
for i in Inventory.objects.filter(images__len=0).all():
    pid = ObjectId(i.product_id)
    p = Product.objects(id=pid).first() if i.product_type == ProductType.NORMAL_PRODUCT else AlloffProduct.objects(id=pid).first()
    i.images = p.images
    
    print(f"Saved {len(i.images)} to inventory #{i.id} ({i.code})")
    i.save()
# Out:
# Saved 7 to inventory #246 (211117-023)
# Saved 15 to inventory #230 (211117-008)
# Saved 6 to inventory #244 (211117-021)
# Saved 10 to inventory #236 (211117-014)
# Saved 5 to inventory #229 (211117-007)
# Saved 6 to inventory #245 (211117-022-R)
# Saved 15 to inventory #231 (211117-009)
# Saved 26 to inventory #208 (211116-001)
# Saved 4 to inventory #225 (211117-003)
# Saved 8 to inventory #234 (211117-012)
# Saved 4 to inventory #224 (211117-002-R)
# Saved 15 to inventory #232 (211117-010)
# Saved 4 to inventory #233 (211117-011)
# Saved 10 to inventory #228 (211117-006)
# Saved 3 to inventory #209 (211116-002)
# Saved 5 to inventory #210 (211116-003)
# Saved 7 to inventory #211 (211116-004)
# Saved 6 to inventory #212 (211116-005)
# Saved 5 to inventory #213 (211117-001)
# Saved 10 to inventory #235 (211117-013)
# Saved 8 to inventory #238 (211117-016)
# Saved 8 to inventory #237 (211117-015)
# Saved 8 to inventory #242 (211117-019)
# Saved 8 to inventory #226 (211117-004)
# ...

# %%
# Out:
# /Users/stephenj/Library/Caches/pypoetry/virtualenvs/alloff-backoffice-server-V9pDS2iq-py3.9/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField ReceivedItem.ordered received a naive datetime (2021-10-29 12:46:40.480000) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/stephenj/Library/Caches/pypoetry/virtualenvs/alloff-backoffice-server-V9pDS2iq-py3.9/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField ReceivedItem.ordered received a naive datetime (2021-10-31 15:12:18.073000) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ...

# %%
# 재고가액추정
amounts = []
for i in Inventory.objects.filter(status=InventoryStatus.IN_STOCK).all():
    amounts.append(
        Product.objects(id=ObjectId(i.product_id)).first().discountedprice if i.product_type == ProductType.NORMAL_PRODUCT else AlloffProduct.objects(id=ObjectId(i.product_id)).first().discountedprice
    )

# %%
sum(amounts)
# Out:
# 5494680
